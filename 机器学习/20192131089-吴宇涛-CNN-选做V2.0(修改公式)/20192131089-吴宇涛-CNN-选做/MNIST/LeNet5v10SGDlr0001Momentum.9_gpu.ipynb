# %%
import torch
from torch.autograd.grad_mode import no_grad 
import torch.nn as NN
import torch.nn.functional as F
import time
from torch.nn.modules import padding 
import torch.optim as optim
from torchvision import datasets
import matplotlib.pyplot as plt
from torchvision import transforms
import numpy as np
from torchsummary import summary

# %%
batch_size=128
learning_rate=1e-4
momentum=0.9
n_epochs=100
start=time.perf_counter()
torch.manual_seed(6)

train_dataset=datasets.MNIST(
    root='./data',train=True,transform=transforms.ToTensor(),download=True)

test_dataset=datasets.MNIST(
    root='./data',train=False,transform=transforms.ToTensor(),download=False)

train_loader=torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,shuffle=True)
test_loader=torch.utils.data.DataLoader(test_dataset,batch_size=batch_size,shuffle=True)

# %%
class CNN(NN.Module):
    def __init__(self,n_featuremap,n_output):
        super().__init__()
        self.L1Conv=NN.Conv2d(n_featuremap,6,5,stride=1,padding=2)
        self.L1Activation=NN.ReLU(inplace=True)
        self.L1Pooling=NN.MaxPool2d(2,2)
        
        self.L2Conv=NN.Conv2d(6,16,5,stride=1,padding=0)
        self.L2Activation=NN.ReLU(inplace=True)
        self.L2Pooling=NN.MaxPool2d(2,2)
        
        self.L3Linear=NN.Linear(400,120)
        self.L3Activation=NN.ReLU(inplace=True)
        
        self.L4Linear=NN.Linear(120,84)
        self.L4Activation=NN.ReLU(inplace=True)        
        
        self.L5Linear=NN.Linear(84,n_output)
    
    def forward(self,x):
        # L1z=self.L1Conv(x)
        # L1a=self.L1Activation(L1z)
        # L1p=self.L1Pooling(L1a)

        # L2z=self.L2Conv(L1p)
        # L2a=self.L2Activation(L2z)
        # L2p=self.L2Pooling(L2a)

        # L3z=self.L3Activation(L2p.view(L2p.size(0),-1))
        # L3a=self.L3Activation(L3z)

        # L4z=self.L4Linear(L3a)
        # L4a=self.L4Activation(L4z)

        # L5z=self.L5Linear(L4a)
        # L5softmax=torch.softmax(L5z,dim=1)
        # L5ouput=torch.log(L5softmax)

        L1z = self.L1Conv(x)
        L1a = self.L1Activation(L1z)
        L1p = self.L1Pooling(L1a)
        L2z = self.L2Conv(L1p)
        L2a = self.L2Activation(L2z)
        L2p = self.L2Pooling(L2a)
        L3z = self.L3Linear(L2p.view(L2p.size(0), -1))
        L3a = self.L3Activation(L3z)
        L4z = self.L4Linear(L3a)
        L4a = torch.relu(L4z)
        L5z = self.L5Linear(L4a)
        L5softmax=torch.softmax(L5z, dim =1)
        L5ouput=torch.log(L5softmax)
        return L5ouput

    def learning(self,X,y,loss_func,optimizer):
        prediction=self.forward(X)
        loss=loss_func(prediction,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        return loss

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(f'we are using GPU device: {torch.cuda.get_device_name(0)}')
else:
    print(f'we are using CPU')
n_featuremap=1
n_output=10
# SMR = CNN(n_featuremap,n_output)
# summary(SMR.to(device), (1,28,28))
# SMR = SMR.to(device)
SMR=CNN(n_featuremap,n_output)
SMR=SMR.to(device)

optimizer=optim.SGD(SMR.parameters(),lr=learning_rate,momentum=momentum)
loss_fn=NN.NLLLoss()
accuracy_tensor_tr=torch.zeros(n_epochs)
accuracy_tensor_te=torch.zeros(n_epochs)
for epoch in range(n_epochs):
    for imgs,labels in train_loader:
        imgs=imgs.to(device)
        labels=labels.to(device)

        batch_size=imgs.shape[0]
        loss=SMR.learning(imgs,labels,loss_fn,optimizer)

    correct_tr=0
    total_tr=0
    with torch.no_grad():
        for imgs,labels in train_loader:
            imgs=imgs.to(device)
            labels=labels.to(device)

            batch_size=imgs.shape[0]
            outputs=SMR.forward(imgs)
            _,predicted=torch.max(outputs,dim=1)
            total_tr+=labels.shape[0]
            correct_tr+=int((predicted==labels).sum())

    correct_te=0
    total_te=0
    with torch.no_grad():
        for imgs,labels in test_loader:
            imgs=imgs.to(device)
            labels=labels.to(device)
            batch_size=imgs.shape[0]
            outputs=SMR.forward(imgs)
            _,predicted=torch.max(outputs,dim=1)
            total_te+=labels.shape[0]
            correct_te+=int((predicted==labels).sum())            
    
    print('Epoch:%d,Loss:%f Accuracy:%f on training set %f on test set' %(epoch,float(loss),correct_tr/total_tr,correct_te/total_te))
    accuracy_tensor_tr[epoch]=correct_tr/total_tr
    accuracy_tensor_te[epoch]=correct_te/total_te    
elapsed=(time.perf_counter()-start)
print('Time used:',elapsed,'s')

torch.save(accuracy_tensor_tr,'./accuracy_tensor_trgpu1.pt')
torch.save(accuracy_tensor_te,'./accuracy_tensor_tegpu1.pt')


fig=plt.figure(figsize=(10,8))
plt.plot(range(1,n_epochs+1),accuracy_tensor_tr,label='Training accuracy')
plt.plot(range(1,n_epochs+1),accuracy_tensor_te,label='Test accuracy')

plt.xlabel('epochs',fontsize=20)
plt.ylabel('accuracy',fontsize=20)
plt.xlim(0,n_epochs+1)
plt.legend(fontsize=18)
plt.tight_layout()
plt.tick_params(axis='both',labelsize=18)
fig.savefig('accuracy_plotgpu1.png',bbox_inches='tight')
fig.savefig('accuracy_plotgpu1.eps',bbox_inches='tight')
fig.savefig('accuracy_plotgpu1.pdf',bbox_inches='tight')
# Out:
# we are using GPU device: GeForce GTX 1650
# Epoch:0,Loss:2.295285 Accuracy:0.112367 on training set 0.113500 on test set
# Epoch:1,Loss:2.296202 Accuracy:0.112367 on training set 0.113500 on test set
# Epoch:2,Loss:2.298670 Accuracy:0.112400 on training set 0.113500 on test set
# Epoch:3,Loss:2.295857 Accuracy:0.112683 on training set 0.113900 on test set
# Epoch:4,Loss:2.297020 Accuracy:0.114833 on training set 0.115600 on test set
# Epoch:5,Loss:2.300061 Accuracy:0.120933 on training set 0.120300 on test set
# Epoch:6,Loss:2.292691 Accuracy:0.133000 on training set 0.131500 on test set
# Epoch:7,Loss:2.293423 Accuracy:0.145467 on training set 0.145700 on test set
# Epoch:8,Loss:2.293811 Accuracy:0.165267 on training set 0.168700 on test set
# Epoch:9,Loss:2.277070 Accuracy:0.217650 on training set 0.223900 on test set
# Epoch:10,Loss:2.283105 Accuracy:0.293550 on training set 0.304600 on test set
# Epoch:11,Loss:2.270525 Accuracy:0.347217 on training set 0.357000 on test set
# Epoch:12,Loss:2.266556 Accuracy:0.396083 on training set 0.398100 on test set
# Epoch:13,Loss:2.254865 Accuracy:0.436900 on training set 0.437300 on test set
# Epoch:14,Loss:2.222938 Accuracy:0.467067 on training set 0.466900 on test set
# Epoch:15,Loss:2.213235 Accuracy:0.473950 on training set 0.474800 on test set
# Epoch:16,Loss:2.151184 Accuracy:0.475300 on training set 0.476100 on test set
# Epoch:17,Loss:1.961083 Accuracy:0.532350 on training set 0.533000 on test set
# Epoch:18,Loss:1.681050 Accuracy:0.634267 on training set 0.644300 on test set
# Epoch:19,Loss:1.146644 Accuracy:0.721700 on training set 0.734600 on test set
# Epoch:20,Loss:0.738699 Accuracy:0.770833 on training set 0.784000 on test set
# Epoch:21,Loss:0.587037 Accuracy:0.801267 on training set 0.811500 on test set
# Epoch:22,Loss:0.596139 Accuracy:0.820900 on training set 0.829900 on test set
# Epoch:23,Loss:0.498506 Accuracy:0.834250 on training set 0.842400 on test set
# Epoch:24,Loss:0.594112 Accuracy:0.847150 on training set 0.855300 on test set
# Epoch:25,Loss:0.601985 Accuracy:0.855967 on training set 0.866700 on test set
# Epoch:26,Loss:0.321823 Accuracy:0.865317 on training set 0.875600 on test set
# Epoch:27,Loss:0.460584 Accuracy:0.874200 on training set 0.881900 on test set
# Epoch:28,Loss:0.451371 Accuracy:0.878467 on training set 0.884700 on test set
# Epoch:29,Loss:0.383400 Accuracy:0.885933 on training set 0.890600 on test set
# Epoch:30,Loss:0.367837 Accuracy:0.890350 on training set 0.896000 on test set
# Epoch:31,Loss:0.385356 Accuracy:0.894133 on training set 0.899700 on test set
# Epoch:32,Loss:0.208644 Accuracy:0.897950 on training set 0.903500 on test set
# Epoch:33,Loss:0.223224 Accuracy:0.902583 on training set 0.909100 on test set
# Epoch:34,Loss:0.250417 Accuracy:0.905867 on training set 0.910700 on test set
# Epoch:35,Loss:0.280253 Accuracy:0.907667 on training set 0.912900 on test set
# Epoch:36,Loss:0.148756 Accuracy:0.910800 on training set 0.915900 on test set
# Epoch:37,Loss:0.237286 Accuracy:0.913750 on training set 0.919700 on test set
# Epoch:38,Loss:0.419308 Accuracy:0.915883 on training set 0.921200 on test set
# Epoch:39,Loss:0.245764 Accuracy:0.918967 on training set 0.924600 on test set
# Epoch:40,Loss:0.279159 Accuracy:0.919883 on training set 0.922900 on test set
# Epoch:41,Loss:0.149008 Accuracy:0.922717 on training set 0.927100 on test set
# Epoch:42,Loss:0.232930 Accuracy:0.924450 on training set 0.929100 on test set
# Epoch:43,Loss:0.344431 Accuracy:0.926433 on training set 0.932500 on test set
# Epoch:44,Loss:0.350868 Accuracy:0.928450 on training set 0.934700 on test set
# Epoch:45,Loss:0.303062 Accuracy:0.929833 on training set 0.935500 on test set
# Epoch:46,Loss:0.300601 Accuracy:0.931383 on training set 0.937100 on test set
# Epoch:47,Loss:0.167227 Accuracy:0.932967 on training set 0.937800 on test set
# Epoch:48,Loss:0.171366 Accuracy:0.935483 on training set 0.940400 on test set
# Epoch:49,Loss:0.210962 Accuracy:0.937000 on training set 0.940800 on test set
# Epoch:50,Loss:0.225699 Accuracy:0.938217 on training set 0.943000 on test set
# Epoch:51,Loss:0.219634 Accuracy:0.939233 on training set 0.943300 on test set
# Epoch:52,Loss:0.213741 Accuracy:0.941100 on training set 0.944400 on test set
# Epoch:53,Loss:0.125065 Accuracy:0.941650 on training set 0.945600 on test set
# Epoch:54,Loss:0.155654 Accuracy:0.943550 on training set 0.947200 on test set
# Epoch:55,Loss:0.129836 Accuracy:0.943717 on training set 0.947600 on test set
# Epoch:56,Loss:0.152168 Accuracy:0.945350 on training set 0.948800 on test set
# Epoch:57,Loss:0.161671 Accuracy:0.946650 on training set 0.950600 on test set
# Epoch:58,Loss:0.150874 Accuracy:0.947917 on training set 0.952700 on test set
# Epoch:59,Loss:0.225479 Accuracy:0.948817 on training set 0.952600 on test set
# Epoch:60,Loss:0.165988 Accuracy:0.949700 on training set 0.953600 on test set
# Epoch:61,Loss:0.119130 Accuracy:0.950917 on training set 0.955100 on test set
# Epoch:62,Loss:0.210415 Accuracy:0.952617 on training set 0.956700 on test set
# Epoch:63,Loss:0.146738 Accuracy:0.952983 on training set 0.957700 on test set
# Epoch:64,Loss:0.167260 Accuracy:0.953950 on training set 0.959100 on test set
# Epoch:65,Loss:0.240709 Accuracy:0.954283 on training set 0.957700 on test set
# Epoch:66,Loss:0.142824 Accuracy:0.954717 on training set 0.958400 on test set
# Epoch:67,Loss:0.107705 Accuracy:0.956133 on training set 0.959900 on test set
# Epoch:68,Loss:0.064904 Accuracy:0.957317 on training set 0.961200 on test set
# Epoch:69,Loss:0.113479 Accuracy:0.957800 on training set 0.961600 on test set
# Epoch:70,Loss:0.124650 Accuracy:0.957950 on training set 0.961500 on test set
# Epoch:71,Loss:0.181867 Accuracy:0.959100 on training set 0.961400 on test set
# Epoch:72,Loss:0.076310 Accuracy:0.959783 on training set 0.962700 on test set
# Epoch:73,Loss:0.104929 Accuracy:0.960383 on training set 0.963500 on test set
# Epoch:74,Loss:0.141920 Accuracy:0.960967 on training set 0.963600 on test set
# Epoch:75,Loss:0.122747 Accuracy:0.962550 on training set 0.964800 on test set
# Epoch:76,Loss:0.083100 Accuracy:0.960833 on training set 0.962800 on test set
# Epoch:77,Loss:0.051478 Accuracy:0.962350 on training set 0.965300 on test set
# Epoch:78,Loss:0.112773 Accuracy:0.963200 on training set 0.965800 on test set
# Epoch:79,Loss:0.129849 Accuracy:0.962700 on training set 0.965100 on test set
# Epoch:80,Loss:0.127084 Accuracy:0.964283 on training set 0.966400 on test set
# Epoch:81,Loss:0.186901 Accuracy:0.964850 on training set 0.967300 on test set
# Epoch:82,Loss:0.084579 Accuracy:0.965100 on training set 0.967500 on test set
# Epoch:83,Loss:0.087526 Accuracy:0.966383 on training set 0.968900 on test set
# Epoch:84,Loss:0.160514 Accuracy:0.965983 on training set 0.968200 on test set
# Epoch:85,Loss:0.127670 Accuracy:0.966200 on training set 0.969200 on test set
# Epoch:86,Loss:0.128644 Accuracy:0.966350 on training set 0.968900 on test set
# Epoch:87,Loss:0.140900 Accuracy:0.967233 on training set 0.969900 on test set
# Epoch:88,Loss:0.104624 Accuracy:0.967817 on training set 0.968700 on test set
# Epoch:89,Loss:0.098776 Accuracy:0.967200 on training set 0.969800 on test set
# Epoch:90,Loss:0.264562 Accuracy:0.967617 on training set 0.969100 on test set
# Epoch:91,Loss:0.090006 Accuracy:0.966600 on training set 0.968200 on test set
# Epoch:92,Loss:0.058045 Accuracy:0.969283 on training set 0.970900 on test set
# Epoch:93,Loss:0.158789 Accuracy:0.970117 on training set 0.972300 on test set
# Epoch:94,Loss:0.116286 Accuracy:0.969950 on training set 0.972000 on test set
# Epoch:95,Loss:0.123875 Accuracy:0.969767 on training set 0.971100 on test set
# Epoch:96,Loss:0.071934 Accuracy:0.970467 on training set 0.973000 on test set
# Epoch:97,Loss:0.102953 Accuracy:0.969733 on training set 0.974000 on test set
# Epoch:98,Loss:0.063403 Accuracy:0.971317 on training set 0.972700 on test set
# Epoch:99,Loss:0.128210 Accuracy:0.970917 on training set 0.972900 on test set
# Time used: 1118.7821873999999 s
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
